# %%
# coding: utf-8

# In[ ]:

from __future__ import print_function

import sys, os
import numpy as np
from time import time
import matplotlib.pyplot as plt 

sys.path.append('/home/xilinx')
os.environ['XILINX_XRT'] = '/usr'
from pynq import Overlay
from pynq import allocate

if __name__ == "__main__":
    print("Entry:", sys.argv[0])
    print("System argument(s):", len(sys.argv))
    print("Start of \"" + sys.argv[0] + "\"")
    
    # Overlay
    ol = Overlay("FFT_iFFT.bit")
    ipFFT  = ol.FFT_0  
    ipiFFT = ol.iFFT_0

    # Memory allocate
    inBufferFFT  = allocate(shape=(1024,), dtype=np.float64)
    inBufferiFFT = allocate(shape=(1024,), dtype=np.float64)
        
    # ============= Set Kernel Argument ==============
    # control
    # 0x00 : Control signals
    #        bit 0  - ap_start (Read/Write/COH)
    #        bit 1  - ap_done (Read/COR)
    #        bit 2  - ap_idle (Read)
    # 0x10 : Data signal of f
    #        bit 31~0 - f[31:0] (Read/Write)
    # 0x14 : Data signal of f
    #        bit 31~0 - f[63:32] (Read/Write)
    # 0x1c : Data signal of logn
    #        bit 31~0 - logn[31:0] (Read/Write)
    logn = 10
    ipFFT.write(0x1C, logn) # Coefficient
    ipiFFT.write(0x1C, logn)
    ipFFT.write(0x10, inBufferFFT.device_address) # 0x10 bit 31:0
    ipiFFT.write(0x10, inBufferiFFT.device_address) # 0x10 bit 31:0

    # ================ Data Transfer =================
    with open("FFT_in.txt", "r+") as FFT_in:
        for i in range(1024):
            line = FFT_in.readline()
            inBufferFFT[i] = float(line)

    timeKernelStart = time()
    ipFFT.write(0x00, 0x01) # 0x00: bit 0: 0->1: start
    while (ipFFT.read(0x00) & 0x4) == 0x0:
        continue
    timeKernelEnd = time()
    print("FFT execution time: " + str(timeKernelEnd - timeKernelStart) + " s")
    
    for i in range(1024):
        inBufferiFFT[i] = inBufferFFT[i]
    timeKernelStart = time()
    ipiFFT.write(0x00, 0x01)
    while (ipiFFT.read(0x00) & 0x4) == 0x0:
        continue
    timeKernelEnd = time()
    print("iFFT execution time: " + str(timeKernelEnd - timeKernelStart) + " s")
    # ================== Compare =====================
    error_cnt = 0
    
    with open("FFT_in.txt" , "r") as result:
        for i in range(1024):
            line = result.readline()
            golden = float(line)

            if round(inBufferiFFT[i], 5) != golden:
                print(f"Failed, expect value: {golden:.17f}")
                error_cnt += 1
            else:
                print(f"{i:4d} Calculate value: {round(inBufferiFFT[i], 5):10f}")

    if error_cnt == 0:
        print("Test Passed!!")
    else:
        print("Test Failed!!")

    print("============================")
    print("Exit process")
# Out:
# Entry: /usr/local/share/pynq-venv/lib/python3.8/site-packages/ipykernel_launcher.py
# System argument(s): 3
# Start of "/usr/local/share/pynq-venv/lib/python3.8/site-packages/ipykernel_launcher.py"
# FFT execution time: 0.002044677734375 s
# iFFT execution time: 0.0036749839782714844 s
#    0 Calculate value: 5856.000000
#    1 Calculate value: 9672.000000
#    2 Calculate value: 354.000000
#    3 Calculate value: 9719.000000
#    4 Calculate value: 7445.000000
#    5 Calculate value: 6283.000000
#    6 Calculate value: 10462.000000
#    7 Calculate value: 8588.000000
#    8 Calculate value:  85.000000
#    9 Calculate value: 3840.000000
#   10 Calculate value: 154.000000
#   11 Calculate value: 4853.000000
#   12 Calculate value: 9810.000000
#   13 Calculate value: 2498.000000
#   14 Calculate value: 6289.000000
#   15 Calculate value: 11201.000000
#   16 Calculate value: 10788.000000
#   17 Calculate value: 1348.000000
#   18 Calculate value: 4887.000000
#   19 Calculate value: 9929.000000
#   20 Calculate value: 6350.000000
#   21 Calculate value: 11349.000000
#   22 Calculate value: 9022.000000
#   23 Calculate value: 8339.000000
#   24 Calculate value: 1628.000000
#   25 Calculate value: 6696.000000
#   26 Calculate value: 7021.000000
#   27 Calculate value: 7449.000000
#   28 Calculate value: 11889.000000
#   29 Calculate value: 6671.000000
#   30 Calculate value: 6476.000000
#   31 Calculate value: 8912.000000
#   32 Calculate value: 5472.000000
#   33 Calculate value: 9103.000000
#   34 Calculate value: 11621.000000
#   35 Calculate value: 4985.000000
#   36 Calculate value: 11799.000000
#   37 Calculate value: 7779.000000
#   38 Calculate value: 6236.000000
#   39 Calculate value: 4880.000000
#   40 Calculate value: 3469.000000
#   41 Calculate value: 2493.000000
#   42 Calculate value: 455.000000
#   43 Calculate value: 8968.000000
#   44 Calculate value: 7869.000000
#   45 Calculate value: 9871.000000
#   46 Calculate value: 3795.000000
#   47 Calculate value: 10502.000000
#   48 Calculate value:  24.000000
#   49 Calculate value: 9231.000000
#   50 Calculate value: 1668.000000
#   51 Calculate value: 10999.000000
#   52 Calculate value: 5937.000000
#   53 Calculate value: 10579.000000
#   54 Calculate value: 6780.000000
#   55 Calculate value: 1407.000000
#   56 Calculate value: 149.000000
#   57 Calculate value: 922.000000
#   58 Calculate value: 884.000000
#   59 Calculate value: 5092.000000
#   60 Calculate value: 7485.000000
#   61 Calculate value: 10910.000000
#   62 Calculate value: 3231.000000
#   63 Calculate value: 9806.000000
#   64 Calculate value: 9181.000000
#   65 Calculate value: 4821.000000
#   66 Calculate value: 7829.000000
#   67 Calculate value: 10197.000000
#   68 Calculate value: 9857.000000
#   69 Calculate value: 1682.000000
#   70 Calculate value: 5559.000000
#   71 Calculate value: 9831.000000
#   72 Calculate value: 10176.000000
#   73 Calculate value: 3765.000000
#   74 Calculate value: 10055.000000
#   75 Calculate value: 12080.000000
#   76 Calculate value: 5137.000000
#   77 Calculate value: 11767.000000
#   78 Calculate value: 7822.000000
#   79 Calculate value: 2386.000000
#   80 Calculate value: 7572.000000
#   81 Calculate value: 7172.000000
#   82 Calculate value: 2543.000000
#   83 Calculate value: 3735.000000
#   84 Calculate value: 5842.000000
#   85 Calculate value: 9635.000000
#   86 Calculate value: 6402.000000
#   87 Calculate value: 11416.000000
#   88 Calculate value: 8387.000000
#   89 Calculate value: 9006.000000
#   90 Calculate value: 9905.000000
#   91 Calculate value: 6464.000000
#   92 Calculate value: 7783.000000
#   93 Calculate value: 8087.000000
#   94 Calculate value: 469.000000
#   95 Calculate value: 5723.000000
#   96 Calculate value: 8863.000000
#   97 Calculate value: 1320.000000
#   98 Calculate value: 4171.000000
#   99 Calculate value: 4942.000000
#  100 Calculate value: 8036.000000
#  101 Calculate value: 7169.000000
#  102 Calculate value: 1063.000000
#  103 Calculate value: 1414.000000
#  104 Calculate value: 4290.000000
#  105 Calculate value: 4015.000000
#  106 Calculate value: 2886.000000
#  107 Calculate value: 5520.000000
#  108 Calculate value: 7406.000000
#  109 Calculate value: 6283.000000
#  110 Calculate value: 1727.000000
#  111 Calculate value: 757.000000
#  112 Calculate value: 2589.000000
#  113 Calculate value: 5012.000000
#  114 Calculate value: 10398.000000
#  115 Calculate value: 347.000000
#  116 Calculate value: 2945.000000
#  117 Calculate value: 4993.000000
#  118 Calculate value: 3535.000000
#  119 Calculate value: 12102.000000
#  120 Calculate value: 4117.000000
#  121 Calculate value: 10037.000000
#  122 Calculate value: 9469.000000
#  123 Calculate value: 3593.000000
#  124 Calculate value: 607.000000
#  125 Calculate value: 6667.000000
#  126 Calculate value: 11300.000000
#  127 Calculate value: 2911.000000
#  128 Calculate value: 5494.000000
#  129 Calculate value: 10477.000000
#  130 Calculate value: 4953.000000
#  131 Calculate value: 5479.000000
#  132 Calculate value: 8012.000000
#  133 Calculate value: 6745.000000
#  134 Calculate value: 4327.000000
#  135 Calculate value: 7739.000000
#  136 Calculate value: 4946.000000
#  137 Calculate value: 1830.000000
#  138 Calculate value: 8740.000000
#  139 Calculate value: 11249.000000
#  140 Calculate value: 10418.000000
#  141 Calculate value: 1337.000000
#  142 Calculate value: 2159.000000
#  143 Calculate value: 6103.000000
#  144 Calculate value: 10419.000000
#  145 Calculate value: 6852.000000
#  146 Calculate value: 10918.000000
#  147 Calculate value: 634.000000
#  148 Calculate value: 2147.000000
#  149 Calculate value: 11027.000000
#  150 Calculate value: 115.000000
#  151 Calculate value: 11934.000000
#  152 Calculate value: 2008.000000
#  153 Calculate value: 5283.000000
#  154 Calculate value: 9696.000000
#  155 Calculate value: 5339.000000
#  156 Calculate value: 8111.000000
#  157 Calculate value: 10592.000000
#  158 Calculate value: 4456.000000
#  159 Calculate value: 3920.000000
#  160 Calculate value: 11139.000000
#  161 Calculate value: 7080.000000
#  162 Calculate value: 6830.000000
#  163 Calculate value: 275.000000
#  164 Calculate value: 11516.000000
#  165 Calculate value: 7928.000000
#  166 Calculate value: 8530.000000
#  167 Calculate value: 7695.000000
#  168 Calculate value: 1683.000000
#  169 Calculate value: 11501.000000
#  170 Calculate value: 5871.000000
#  171 Calculate value: 11165.000000
#  172 Calculate value: 7100.000000
#  173 Calculate value: 810.000000
#  174 Calculate value: 7857.000000
#  175 Calculate value: 5717.000000
#  176 Calculate value: 10166.000000
#  177 Calculate value: 9130.000000
#  178 Calculate value: 11194.000000
#  179 Calculate value: 10671.000000
#  180 Calculate value: 536.000000
#  181 Calculate value: 737.000000
#  182 Calculate value: 12248.000000
#  183 Calculate value: 6353.000000
#  184 Calculate value: 8544.000000
#  185 Calculate value: 3937.000000
#  186 Calculate value: 5034.000000
#  187 Calculate value: 3917.000000
#  188 Calculate value: 8711.000000
#  189 Calculate value: 8462.000000
#  190 Calculate value: 10378.000000
#  191 Calculate value: 3165.000000
#  192 Calculate value: 4493.000000
#  193 Calculate value: 9024.000000
#  194 Calculate value: 2140.000000
#  195 Calculate value: 9035.000000
#  196 Calculate value: 7460.000000
#  197 Calculate value: 4719.000000
#  198 Calculate value: 3552.000000
#  199 Calculate value: 7015.000000
#  200 Calculate value: 4469.000000
#  201 Calculate value: 9174.000000
#  202 Calculate value: 5994.000000
#  203 Calculate value: 9150.000000
#  204 Calculate value: 6422.000000
#  205 Calculate value: 11130.000000
#  206 Calculate value: 3000.000000
#  207 Calculate value: 1976.000000
#  208 Calculate value: 8802.000000
#  209 Calculate value: 2033.000000
#  210 Calculate value: 11441.000000
#  211 Calculate value: 1864.000000
#  212 Calculate value: 8543.000000
#  213 Calculate value: 611.000000
#  214 Calculate value: 2935.000000
#  215 Calculate value: 11438.000000
#  216 Calculate value: 2307.000000
#  217 Calculate value: 5860.000000
#  218 Calculate value: 5554.000000
#  219 Calculate value: 741.000000
#  220 Calculate value: 6519.000000
#  221 Calculate value: 8885.000000
#  222 Calculate value: 2954.000000
#  223 Calculate value: 5716.000000
#  224 Calculate value: 6994.000000
#  225 Calculate value: 3536.000000
#  226 Calculate value: 7164.000000
#  227 Calculate value: 5280.000000
#  228 Calculate value: 3461.000000
#  229 Calculate value: 6095.000000
#  230 Calculate value: 5498.000000
#  231 Calculate value: 11397.000000
#  232 Calculate value: 11592.000000
#  233 Calculate value: 9323.000000
#  234 Calculate value: 12119.000000
#  235 Calculate value: 5137.000000
#  236 Calculate value: 2923.000000
#  237 Calculate value: 5547.000000
#  238 Calculate value: 9278.000000
#  239 Calculate value: 6730.000000
#  240 Calculate value: 2513.000000
#  241 Calculate value: 8428.000000
#  242 Calculate value: 10364.000000
#  243 Calculate value: 2322.000000
#  244 Calculate value: 12010.000000
#  245 Calculate value: 11719.000000
#  246 Calculate value: 4476.000000
#  247 Calculate value: 8565.000000
#  248 Calculate value: 1958.000000
#  249 Calculate value: 2343.000000
#  250 Calculate value: 2126.000000
#  251 Calculate value: 6759.000000
#  252 Calculate value: 6207.000000
#  253 Calculate value: 8633.000000
#  254 Calculate value: 9496.000000
#  255 Calculate value: 5827.000000
#  256 Calculate value: 5339.000000
#  257 Calculate value: 2665.000000
#  258 Calculate value: 4457.000000
#  259 Calculate value: 12239.000000
#  260 Calculate value: 6369.000000
#  261 Calculate value: 1174.000000
#  262 Calculate value: 6305.000000
#  263 Calculate value: 10726.000000
#  264 Calculate value: 6062.000000
#  265 Calculate value: 1470.000000
#  266 Calculate value:  40.000000
#  267 Calculate value: 3572.000000
#  268 Calculate value: 5825.000000
#  269 Calculate value: 9256.000000
#  270 Calculate value: 3030.000000
#  271 Calculate value: 8189.000000
#  272 Calculate value: 4495.000000
#  273 Calculate value: 10957.000000
#  274 Calculate value: 7556.000000
#  275 Calculate value: 10444.000000
#  276 Calculate value: 3929.000000
#  277 Calculate value: 3336.000000
#  278 Calculate value: 7719.000000
#  279 Calculate value: 7701.000000
#  280 Calculate value: 3920.000000
#  281 Calculate value: 3240.000000
#  282 Calculate value: 5384.000000
#  283 Calculate value: 6158.000000
#  284 Calculate value: 10377.000000
#  285 Calculate value: 9603.000000
#  286 Calculate value: 11575.000000
#  287 Calculate value: 11387.000000
#  288 Calculate value: 6515.000000
#  289 Calculate value: 383.000000
#  290 Calculate value: 10946.000000
#  291 Calculate value: 10338.000000
#  292 Calculate value: 10925.000000
#  293 Calculate value: 9516.000000
#  294 Calculate value: 2561.000000
#  295 Calculate value: 9248.000000
#  296 Calculate value: 11489.000000
#  297 Calculate value: 5989.000000
#  298 Calculate value: 5931.000000
#  299 Calculate value: 10860.000000
#  300 Calculate value: 5884.000000
#  301 Calculate value: 9448.000000
#  302 Calculate value: 12029.000000
#  303 Calculate value: 4249.000000
#  304 Calculate value: 4721.000000
#  305 Calculate value: 11411.000000
#  306 Calculate value: 6516.000000
#  307 Calculate value: 919.000000
#  308 Calculate value: 9414.000000
#  309 Calculate value: 4021.000000
#  310 Calculate value: 2813.000000
#  311 Calculate value: 6433.000000
#  312 Calculate value: 4060.000000
#  313 Calculate value: 6229.000000
#  314 Calculate value: 9324.000000
#  315 Calculate value: 8396.000000
#  316 Calculate value: 3655.000000
#  317 Calculate value: 4038.000000
#  318 Calculate value: 11401.000000
#  319 Calculate value: 11391.000000
#  320 Calculate value: 6624.000000
#  321 Calculate value: 6965.000000
#  322 Calculate value: 1187.000000
#  323 Calculate value: 7778.000000
#  324 Calculate value: 9525.000000
#  325 Calculate value: 5290.000000
#  326 Calculate value: 4589.000000
#  327 Calculate value: 1770.000000
#  328 Calculate value: 9836.000000
#  329 Calculate value: 1847.000000
#  330 Calculate value: 5239.000000
#  331 Calculate value: 11924.000000
#  332 Calculate value: 4889.000000
#  333 Calculate value: 8212.000000
#  334 Calculate value: 1707.000000
#  335 Calculate value: 5735.000000
#  336 Calculate value: 4974.000000
#  337 Calculate value: 2531.000000
#  338 Calculate value: 449.000000
#  339 Calculate value: 2768.000000
#  340 Calculate value: 12064.000000
#  341 Calculate value: 9859.000000
#  342 Calculate value: 10323.000000
#  343 Calculate value: 3459.000000
#  344 Calculate value: 4735.000000
#  345 Calculate value: 9661.000000
#  346 Calculate value: 384.000000
#  347 Calculate value: 1189.000000
#  348 Calculate value: 7548.000000
#  349 Calculate value: 5661.000000
#  350 Calculate value: 11844.000000
#  351 Calculate value: 9595.000000
#  352 Calculate value: 6749.000000
#  353 Calculate value: 1936.000000
#  354 Calculate value: 6998.000000
#  355 Calculate value: 11774.000000
#  356 Calculate value: 2877.000000
#  357 Calculate value: 3385.000000
#  358 Calculate value: 2207.000000
#  359 Calculate value: 9872.000000
#  360 Calculate value: 4350.000000
#  361 Calculate value: 11077.000000
#  362 Calculate value: 9953.000000
#  363 Calculate value: 455.000000
#  364 Calculate value: 2552.000000
#  365 Calculate value: 8605.000000
#  366 Calculate value: 9946.000000
#  367 Calculate value: 6442.000000
#  368 Calculate value: 7246.000000
#  369 Calculate value: 3157.000000
#  370 Calculate value: 10849.000000
#  371 Calculate value: 4656.000000
#  372 Calculate value: 1667.000000
#  373 Calculate value: 9455.000000
#  374 Calculate value: 1555.000000
#  375 Calculate value: 8596.000000
#  376 Calculate value: 5495.000000
#  377 Calculate value: 888.000000
#  378 Calculate value: 8049.000000
#  379 Calculate value: 11028.000000
#  380 Calculate value: 3015.000000
#  381 Calculate value: 10324.000000
#  382 Calculate value: 2961.000000
#  383 Calculate value: 2816.000000
#  384 Calculate value: 9379.000000
#  385 Calculate value: 8914.000000
#  386 Calculate value: 5548.000000
#  387 Calculate value: 6966.000000
#  388 Calculate value: 8344.000000
#  389 Calculate value: 8972.000000
#  390 Calculate value: 8966.000000
#  391 Calculate value: 224.000000
#  392 Calculate value: 6524.000000
#  393 Calculate value: 7962.000000
#  394 Calculate value: 7014.000000
#  395 Calculate value: 4269.000000
#  396 Calculate value: 11969.000000
#  397 Calculate value: 9655.000000
#  398 Calculate value: 6309.000000
#  399 Calculate value: 11034.000000
#  400 Calculate value: 2971.000000
#  401 Calculate value: 417.000000
#  402 Calculate value: 2194.000000
#  403 Calculate value: 9184.000000
#  404 Calculate value: 8810.000000
#  405 Calculate value: 2677.000000
#  406 Calculate value: 763.000000
#  407 Calculate value: 7385.000000
#  408 Calculate value: 8099.000000
#  409 Calculate value: 1985.000000
#  410 Calculate value: 11618.000000
#  411 Calculate value: 4343.000000
#  412 Calculate value: 4646.000000
#  413 Calculate value: 4330.000000
#  414 Calculate value: 2255.000000
#  415 Calculate value: 3333.000000
#  416 Calculate value: 4466.000000
#  417 Calculate value: 6455.000000
#  418 Calculate value: 7587.000000
#  419 Calculate value: 7483.000000
#  420 Calculate value: 6205.000000
#  421 Calculate value: 4553.000000
#  422 Calculate value: 5597.000000
#  423 Calculate value: 3179.000000
#  424 Calculate value: 6977.000000
#  425 Calculate value: 6462.000000
#  426 Calculate value: 6934.000000
#  427 Calculate value: 7464.000000
#  428 Calculate value: 11732.000000
#  429 Calculate value: 9158.000000
#  430 Calculate value: 7192.000000
#  431 Calculate value: 4401.000000
#  432 Calculate value: 6097.000000
#  433 Calculate value: 11916.000000
#  434 Calculate value: 640.000000
#  435 Calculate value: 9047.000000
#  436 Calculate value: 1129.000000
#  437 Calculate value: 6235.000000
#  438 Calculate value: 7792.000000
#  439 Calculate value: 10154.000000
#  440 Calculate value: 7615.000000
#  441 Calculate value: 11712.000000
#  442 Calculate value: 4726.000000
#  443 Calculate value: 6950.000000
#  444 Calculate value: 4287.000000
#  445 Calculate value: 5438.000000
#  446 Calculate value: 3839.000000
#  447 Calculate value: 3522.000000
#  448 Calculate value: 8654.000000
#  449 Calculate value: 287.000000
#  450 Calculate value: 11696.000000
#  451 Calculate value: 6806.000000
#  452 Calculate value: 2209.000000
#  453 Calculate value: 8790.000000
#  454 Calculate value: 8208.000000
#  455 Calculate value: 9387.000000
#  456 Calculate value: 7654.000000
#  457 Calculate value: 10043.000000
#  458 Calculate value: 11137.000000
#  459 Calculate value: 3879.000000
#  460 Calculate value: 11513.000000
#  461 Calculate value: 11394.000000
#  462 Calculate value: 335.000000
#  463 Calculate value: 3681.000000
#  464 Calculate value: 5862.000000
#  465 Calculate value: 5871.000000
#  466 Calculate value: 3232.000000
#  467 Calculate value:  91.000000
#  468 Calculate value: 6080.000000
#  469 Calculate value: 3237.000000
#  470 Calculate value: 4310.000000
#  471 Calculate value: 6144.000000
#  472 Calculate value: 12168.000000
#  473 Calculate value: 10215.000000
#  474 Calculate value: 8661.000000
#  475 Calculate value: 10679.000000
#  476 Calculate value: 10909.000000
#  477 Calculate value: 2373.000000
#  478 Calculate value: 7161.000000
#  479 Calculate value: 7496.000000
#  480 Calculate value: 11050.000000
#  481 Calculate value: 6570.000000
#  482 Calculate value: 555.000000
#  483 Calculate value: 11779.000000
#  484 Calculate value: 1676.000000
#  485 Calculate value: 3613.000000
#  486 Calculate value: 8205.000000
#  487 Calculate value: 7877.000000
#  488 Calculate value: 2609.000000
#  489 Calculate value: 3911.000000
#  490 Calculate value: 11342.000000
#  491 Calculate value: 570.000000
#  492 Calculate value: 8790.000000
#  493 Calculate value: 11693.000000
#  494 Calculate value: 6020.000000
#  495 Calculate value: 2933.000000
#  496 Calculate value: 5761.000000
#  497 Calculate value: 7284.000000
#  498 Calculate value: 1002.000000
#  499 Calculate value: 8389.000000
#  500 Calculate value: 8784.000000
#  501 Calculate value: 2452.000000
#  502 Calculate value: 5762.000000
#  503 Calculate value: 3906.000000
#  504 Calculate value: 7918.000000
#  505 Calculate value: 4778.000000
#  506 Calculate value: 461.000000
#  507 Calculate value: 7072.000000
#  508 Calculate value: 5622.000000
#  509 Calculate value: 7193.000000
#  510 Calculate value: 11329.000000
#  511 Calculate value: 3073.000000
#  512 Calculate value: 6858.000000
#  513 Calculate value: 3900.000000
#  514 Calculate value: 6287.000000
#  515 Calculate value: 11292.000000
#  516 Calculate value: 11080.000000
#  517 Calculate value: 6353.000000
#  518 Calculate value: 3629.000000
#  519 Calculate value: 8090.000000
#  520 Calculate value: 11688.000000
#  521 Calculate value: 9714.000000
#  522 Calculate value: 7511.000000
#  523 Calculate value: 2563.000000
#  524 Calculate value: 10715.000000
#  525 Calculate value: 2508.000000
#  526 Calculate value: 7801.000000
#  527 Calculate value: 2557.000000
#  528 Calculate value: 916.000000
#  529 Calculate value: 1295.000000
#  530 Calculate value: 6651.000000
#  531 Calculate value: 6418.000000
#  532 Calculate value: 10108.000000
#  533 Calculate value: 11217.000000
#  534 Calculate value: 9338.000000
#  535 Calculate value: 6737.000000
#  536 Calculate value: 10409.000000
#  537 Calculate value: 2959.000000
#  538 Calculate value: 1293.000000
#  539 Calculate value: 9572.000000
#  540 Calculate value: 12032.000000
#  541 Calculate value: 10789.000000
#  542 Calculate value: 11653.000000
#  543 Calculate value: 10462.000000
#  544 Calculate value: 7187.000000
#  545 Calculate value: 8367.000000
#  546 Calculate value: 2531.000000
#  547 Calculate value: 12179.000000
#  548 Calculate value: 3863.000000
#  549 Calculate value: 4057.000000
#  550 Calculate value: 9816.000000
#  551 Calculate value: 734.000000
#  552 Calculate value: 3389.000000
#  553 Calculate value: 12096.000000
#  554 Calculate value: 7233.000000
#  555 Calculate value: 4960.000000
#  556 Calculate value: 4570.000000
#  557 Calculate value: 2658.000000
#  558 Calculate value: 820.000000
#  559 Calculate value: 6382.000000
#  560 Calculate value: 632.000000
#  561 Calculate value: 11023.000000
#  562 Calculate value: 7280.000000
#  563 Calculate value: 3435.000000
#  564 Calculate value: 2482.000000
#  565 Calculate value: 1913.000000
#  566 Calculate value: 7023.000000
#  567 Calculate value: 9533.000000
#  568 Calculate value: 10280.000000
#  569 Calculate value: 6081.000000
#  570 Calculate value: 3646.000000
#  571 Calculate value: 12266.000000
#  572 Calculate value: 424.000000
#  573 Calculate value: 8733.000000
#  574 Calculate value: 4725.000000
#  575 Calculate value: 1539.000000
#  576 Calculate value: 6704.000000
#  577 Calculate value: 9764.000000
#  578 Calculate value: 6520.000000
#  579 Calculate value: 7244.000000
#  580 Calculate value: 3443.000000
#  581 Calculate value: 10494.000000
#  582 Calculate value: 11916.000000
#  583 Calculate value: 11944.000000
#  584 Calculate value: 3767.000000
#  585 Calculate value: 2789.000000
#  586 Calculate value: 5669.000000
#  587 Calculate value: 9859.000000
#  588 Calculate value: 641.000000
#  589 Calculate value: 443.000000
#  590 Calculate value: 11076.000000
#  591 Calculate value: 2536.000000
#  592 Calculate value: 3534.000000
#  593 Calculate value: 8390.000000
#  594 Calculate value: 11788.000000
#  595 Calculate value: 7339.000000
#  596 Calculate value: 5206.000000
#  597 Calculate value: 760.000000
#  598 Calculate value: 9294.000000
#  599 Calculate value: 9545.000000
#  600 Calculate value: 8756.000000
#  601 Calculate value: 6034.000000
#  602 Calculate value: 9787.000000
#  603 Calculate value: 4303.000000
#  604 Calculate value: 1043.000000
#  605 Calculate value: 5575.000000
#  606 Calculate value: 860.000000
#  607 Calculate value: 2621.000000
#  608 Calculate value: 11280.000000
#  609 Calculate value: 12077.000000
#  610 Calculate value: 8035.000000
#  611 Calculate value: 5223.000000
#  612 Calculate value: 4583.000000
#  613 Calculate value: 7951.000000
#  614 Calculate value: 11222.000000
#  615 Calculate value: 10971.000000
#  616 Calculate value: 3537.000000
#  617 Calculate value: 7731.000000
#  618 Calculate value: 8094.000000
#  619 Calculate value: 5838.000000
#  620 Calculate value: 223.000000
#  621 Calculate value: 4275.000000
#  622 Calculate value: 9957.000000
#  623 Calculate value: 2084.000000
#  624 Calculate value: 5955.000000
#  625 Calculate value: 4011.000000
#  626 Calculate value: 7657.000000
#  627 Calculate value: 9173.000000
#  628 Calculate value: 3597.000000
#  629 Calculate value: 2712.000000
#  630 Calculate value: 10725.000000
#  631 Calculate value: 10346.000000
#  632 Calculate value: 3651.000000
#  633 Calculate value: 350.000000
#  634 Calculate value: 3169.000000
#  635 Calculate value: 11400.000000
#  636 Calculate value: 1825.000000
#  637 Calculate value: 5049.000000
#  638 Calculate value: 7806.000000
#  639 Calculate value: 1173.000000
#  640 Calculate value: 11542.000000
#  641 Calculate value: 8543.000000
#  642 Calculate value: 7648.000000
#  643 Calculate value: 8199.000000
#  644 Calculate value: 4681.000000
#  645 Calculate value: 7054.000000
#  646 Calculate value: 1808.000000
#  647 Calculate value: 2798.000000
#  648 Calculate value: 2394.000000
#  649 Calculate value: 3944.000000
#  650 Calculate value: 5883.000000
#  651 Calculate value: 11843.000000
#  652 Calculate value: 1753.000000
#  653 Calculate value: 10760.000000
#  654 Calculate value: 8979.000000
#  655 Calculate value: 11827.000000
#  656 Calculate value: 6778.000000
#  657 Calculate value: 8584.000000
#  658 Calculate value: 6868.000000
#  659 Calculate value: 4747.000000
#  660 Calculate value: 6676.000000
#  661 Calculate value: 5529.000000
#  662 Calculate value: 4707.000000
#  663 Calculate value: 9596.000000
#  664 Calculate value: 5927.000000
#  665 Calculate value: 11200.000000
#  666 Calculate value: 12274.000000
#  667 Calculate value: 6497.000000
#  668 Calculate value: 7278.000000
#  669 Calculate value: 9540.000000
#  670 Calculate value: 7538.000000
#  671 Calculate value: 2256.000000
#  672 Calculate value: 11887.000000
#  673 Calculate value: 5972.000000
#  674 Calculate value: 11673.000000
#  675 Calculate value: 10582.000000
#  676 Calculate value: 7963.000000
#  677 Calculate value: 9216.000000
#  678 Calculate value: 7581.000000
#  679 Calculate value: 10778.000000
#  680 Calculate value: 10853.000000
#  681 Calculate value: 3564.000000
#  682 Calculate value: 9854.000000
#  683 Calculate value: 10547.000000
#  684 Calculate value: 5543.000000
#  685 Calculate value: 11609.000000
#  686 Calculate value: 3186.000000
#  687 Calculate value: 2957.000000
#  688 Calculate value: 936.000000
#  689 Calculate value: 8315.000000
#  690 Calculate value: 4490.000000
#  691 Calculate value: 7193.000000
#  692 Calculate value: 10426.000000
#  693 Calculate value: 6110.000000
#  694 Calculate value: 11637.000000
#  695 Calculate value: 7138.000000
#  696 Calculate value: 8593.000000
#  697 Calculate value: 7410.000000
#  698 Calculate value: 5410.000000
#  699 Calculate value: 3688.000000
#  700 Calculate value: 10817.000000
#  701 Calculate value: 7093.000000
#  702 Calculate value: 1293.000000
#  703 Calculate value: 6357.000000
#  704 Calculate value: 10232.000000
#  705 Calculate value: 10823.000000
#  706 Calculate value: 4042.000000
#  707 Calculate value: 5633.000000
#  708 Calculate value: 1375.000000
#  709 Calculate value: 3747.000000
#  710 Calculate value: 7271.000000
#  711 Calculate value: 4427.000000
#  712 Calculate value: 1849.000000
#  713 Calculate value: 3352.000000
#  714 Calculate value: 318.000000
#  715 Calculate value: 3508.000000
#  716 Calculate value: 2272.000000
#  717 Calculate value: 10129.000000
#  718 Calculate value: 10829.000000
#  719 Calculate value: 5116.000000
#  720 Calculate value: 2567.000000
#  721 Calculate value: 1578.000000
#  722 Calculate value: 6237.000000
#  723 Calculate value: 989.000000
#  724 Calculate value: 8531.000000
#  725 Calculate value: 469.000000
#  726 Calculate value: 6691.000000
#  727 Calculate value: 1502.000000
#  728 Calculate value: 10305.000000
#  729 Calculate value: 7559.000000
#  730 Calculate value: 10900.000000
#  731 Calculate value: 11630.000000
#  732 Calculate value: 4216.000000
#  733 Calculate value: 10706.000000
#  734 Calculate value: 8369.000000
#  735 Calculate value: 3183.000000
#  736 Calculate value: 9266.000000
#  737 Calculate value: 11177.000000
#  738 Calculate value: 2421.000000
#  739 Calculate value: 3305.000000
#  740 Calculate value: 2495.000000
#  741 Calculate value: 10760.000000
#  742 Calculate value: 1992.000000
#  743 Calculate value: 4494.000000
#  744 Calculate value: 3514.000000
#  745 Calculate value: 2709.000000
#  746 Calculate value: 8561.000000
#  747 Calculate value: 1209.000000
#  748 Calculate value: 10993.000000
#  749 Calculate value: 9179.000000
#  750 Calculate value: 10532.000000
#  751 Calculate value: 1263.000000
#  752 Calculate value: 5516.000000
#  753 Calculate value: 11765.000000
#  754 Calculate value: 8445.000000
#  755 Calculate value: 2693.000000
#  756 Calculate value: 1111.000000
#  757 Calculate value: 9296.000000
#  758 Calculate value: 3460.000000
#  759 Calculate value: 7372.000000
#  760 Calculate value: 7959.000000
#  761 Calculate value: 6955.000000
#  762 Calculate value: 12257.000000
#  763 Calculate value: 7242.000000
#  764 Calculate value: 9983.000000
#  765 Calculate value: 2468.000000
#  766 Calculate value: 6534.000000
#  767 Calculate value: 2259.000000
#  768 Calculate value: 9198.000000
#  769 Calculate value: 5764.000000
#  770 Calculate value: 7337.000000
#  771 Calculate value: 5300.000000
#  772 Calculate value: 3162.000000
#  773 Calculate value: 8472.000000
#  774 Calculate value: 4976.000000
#  775 Calculate value: 525.000000
#  776 Calculate value: 2903.000000
#  777 Calculate value: 5240.000000
#  778 Calculate value: 3828.000000
#  779 Calculate value: 7315.000000
#  780 Calculate value: 8395.000000
#  781 Calculate value:  22.000000
#  782 Calculate value: 6187.000000
#  783 Calculate value: 5909.000000
#  784 Calculate value: 2705.000000
#  785 Calculate value: 2746.000000
#  786 Calculate value: 8692.000000
#  787 Calculate value: 6759.000000
#  788 Calculate value: 911.000000
#  789 Calculate value: 9111.000000
#  790 Calculate value: 8413.000000
#  791 Calculate value: 933.000000
#  792 Calculate value: 7938.000000
#  793 Calculate value: 8098.000000
#  794 Calculate value: 457.000000
#  795 Calculate value: 2745.000000
#  796 Calculate value: 2143.000000
#  797 Calculate value: 3913.000000
#  798 Calculate value: 648.000000
#  799 Calculate value: 6736.000000
#  800 Calculate value: 8181.000000
#  801 Calculate value: 5411.000000
#  802 Calculate value: 10779.000000
#  803 Calculate value: 10705.000000
#  804 Calculate value: 6067.000000
#  805 Calculate value: 9205.000000
#  806 Calculate value: 10743.000000
#  807 Calculate value: 10356.000000
#  808 Calculate value: 5927.000000
#  809 Calculate value: 11019.000000
#  810 Calculate value: 9355.000000
#  811 Calculate value: 3733.000000
#  812 Calculate value: 11668.000000
#  813 Calculate value: 4808.000000
#  814 Calculate value: 3396.000000
#  815 Calculate value: 581.000000
#  816 Calculate value: 5516.000000
#  817 Calculate value: 3786.000000
#  818 Calculate value: 8937.000000
#  819 Calculate value: 9592.000000
#  820 Calculate value: 10958.000000
#  821 Calculate value: 684.000000
#  822 Calculate value:   9.000000
#  823 Calculate value: 11507.000000
#  824 Calculate value: 7949.000000
#  825 Calculate value: 825.000000
#  826 Calculate value: 992.000000
#  827 Calculate value: 2153.000000
#  828 Calculate value: 4397.000000
#  829 Calculate value: 7207.000000
#  830 Calculate value: 2613.000000
#  831 Calculate value: 2593.000000
#  832 Calculate value: 4230.000000
#  833 Calculate value: 3948.000000
#  834 Calculate value: 6263.000000
#  835 Calculate value: 3018.000000
#  836 Calculate value: 5583.000000
#  837 Calculate value: 6313.000000
#  838 Calculate value: 5092.000000
#  839 Calculate value: 5134.000000
#  840 Calculate value: 6779.000000
#  841 Calculate value: 8149.000000
#  842 Calculate value: 9724.000000
#  843 Calculate value: 8852.000000
#  844 Calculate value: 5238.000000
#  845 Calculate value: 4434.000000
#  846 Calculate value: 6350.000000
#  847 Calculate value: 5796.000000
#  848 Calculate value: 1987.000000
#  849 Calculate value: 5284.000000
#  850 Calculate value: 2095.000000
#  851 Calculate value: 11782.000000
#  852 Calculate value: 3117.000000
#  853 Calculate value: 7591.000000
#  854 Calculate value: 11691.000000
#  855 Calculate value: 3998.000000
#  856 Calculate value: 4838.000000
#  857 Calculate value: 298.000000
#  858 Calculate value: 4268.000000
#  859 Calculate value: 9993.000000
#  860 Calculate value: 11225.000000
#  861 Calculate value: 11223.000000
#  862 Calculate value: 4244.000000
#  863 Calculate value: 9010.000000
#  864 Calculate value: 1279.000000
#  865 Calculate value: 9420.000000
#  866 Calculate value: 7818.000000
#  867 Calculate value: 7942.000000
#  868 Calculate value: 6627.000000
#  869 Calculate value: 2509.000000
#  870 Calculate value: 2456.000000
#  871 Calculate value: 11550.000000
#  872 Calculate value: 3197.000000
#  873 Calculate value: 4337.000000
#  874 Calculate value: 12160.000000
#  875 Calculate value: 8541.000000
#  876 Calculate value: 8316.000000
#  877 Calculate value: 5590.000000
#  878 Calculate value: 11202.000000
#  879 Calculate value: 9465.000000
#  880 Calculate value: 3978.000000
#  881 Calculate value: 3672.000000
#  882 Calculate value: 2339.000000
#  883 Calculate value: 7691.000000
#  884 Calculate value: 5771.000000
#  885 Calculate value: 8381.000000
#  886 Calculate value: 8459.000000
#  887 Calculate value: 6209.000000
#  888 Calculate value: 1021.000000
#  889 Calculate value: 665.000000
#  890 Calculate value: 9588.000000
#  891 Calculate value: 5900.000000
#  892 Calculate value: 5966.000000
#  893 Calculate value: 7372.000000
#  894 Calculate value: 818.000000
#  895 Calculate value: 2956.000000
#  896 Calculate value: 6368.000000
#  897 Calculate value: 9836.000000
#  898 Calculate value: 3991.000000
#  899 Calculate value: 8691.000000
#  900 Calculate value: 7400.000000
#  901 Calculate value: 2830.000000
#  902 Calculate value: 5539.000000
#  903 Calculate value: 7047.000000
#  904 Calculate value: 11858.000000
#  905 Calculate value: 10381.000000
#  906 Calculate value: 3689.000000
#  907 Calculate value: 7071.000000
#  908 Calculate value: 3433.000000
#  909 Calculate value: 4787.000000
#  910 Calculate value: 7316.000000
#  911 Calculate value: 11891.000000
#  912 Calculate value: 954.000000
#  913 Calculate value: 6932.000000
#  914 Calculate value: 432.000000
#  915 Calculate value: 6332.000000
#  916 Calculate value: 5622.000000
#  917 Calculate value: 5057.000000
#  918 Calculate value: 10670.000000
#  919 Calculate value: 690.000000
#  920 Calculate value: 4770.000000
#  921 Calculate value: 9917.000000
#  922 Calculate value: 5953.000000
#  923 Calculate value: 8858.000000
#  924 Calculate value: 8407.000000
#  925 Calculate value: 755.000000
#  926 Calculate value: 6660.000000
#  927 Calculate value: 753.000000
#  928 Calculate value: 6664.000000
#  929 Calculate value: 5068.000000
#  930 Calculate value: 3375.000000
#  931 Calculate value: 1622.000000
#  932 Calculate value: 7096.000000
#  933 Calculate value: 3763.000000
#  934 Calculate value: 5873.000000
#  935 Calculate value: 1412.000000
#  936 Calculate value: 6214.000000
#  937 Calculate value: 10790.000000
#  938 Calculate value: 1338.000000
#  939 Calculate value: 11117.000000
#  940 Calculate value: 9322.000000
#  941 Calculate value: 8155.000000
#  942 Calculate value: 9179.000000
#  943 Calculate value: 8043.000000
#  944 Calculate value: 10635.000000
#  945 Calculate value: 9787.000000
#  946 Calculate value: 12253.000000
#  947 Calculate value: 2304.000000
#  948 Calculate value: 6153.000000
#  949 Calculate value: 384.000000
#  950 Calculate value: 7988.000000
#  951 Calculate value: 11871.000000
#  952 Calculate value: 4125.000000
#  953 Calculate value: 6461.000000
#  954 Calculate value: 1502.000000
#  955 Calculate value: 131.000000
#  956 Calculate value: 3969.000000
#  957 Calculate value: 10969.000000
#  958 Calculate value: 11105.000000
#  959 Calculate value: 11258.000000
#  960 Calculate value: 6726.000000
#  961 Calculate value: 10100.000000
#  962 Calculate value: 5872.000000
#  963 Calculate value: 8513.000000
#  964 Calculate value: 5710.000000
#  965 Calculate value: 9680.000000
#  966 Calculate value: 1049.000000
#  967 Calculate value: 7926.000000
#  968 Calculate value: 582.000000
#  969 Calculate value: 6033.000000
#  970 Calculate value: 886.000000
#  971 Calculate value: 5772.000000
#  972 Calculate value: 4919.000000
#  973 Calculate value: 2867.000000
#  974 Calculate value: 6311.000000
#  975 Calculate value: 9953.000000
#  976 Calculate value: 9354.000000
#  977 Calculate value: 6924.000000
#  978 Calculate value: 193.000000
#  979 Calculate value: 5844.000000
#  980 Calculate value: 7729.000000
#  981 Calculate value: 5066.000000
#  982 Calculate value: 9664.000000
#  983 Calculate value: 11580.000000
#  984 Calculate value: 5521.000000
#  985 Calculate value: 455.000000
#  986 Calculate value: 11189.000000
#  987 Calculate value: 10801.000000
#  988 Calculate value: 1559.000000
#  989 Calculate value: 5754.000000
#  990 Calculate value:   4.000000
#  991 Calculate value: 5265.000000
#  992 Calculate value: 915.000000
#  993 Calculate value: 5725.000000
#  994 Calculate value: 5430.000000
#  995 Calculate value: 10918.000000
#  996 Calculate value: 5851.000000
#  997 Calculate value: 6012.000000
#  998 Calculate value: 10330.000000
#  999 Calculate value: 2482.000000
# 1000 Calculate value: 4025.000000
# 1001 Calculate value: 6231.000000
# 1002 Calculate value: 7545.000000
# 1003 Calculate value: 11241.000000
# 1004 Calculate value: 9675.000000
# 1005 Calculate value: 1985.000000
# 1006 Calculate value: 8639.000000
# 1007 Calculate value: 5134.000000
# 1008 Calculate value: 4303.000000
# 1009 Calculate value: 12177.000000
# 1010 Calculate value: 11175.000000
# 1011 Calculate value: 7180.000000
# 1012 Calculate value: 744.000000
# 1013 Calculate value: 3070.000000
# 1014 Calculate value: 5719.000000
# 1015 Calculate value: 6604.000000
# 1016 Calculate value: 11393.000000
# 1017 Calculate value: 6518.000000
# 1018 Calculate value: 2323.000000
# 1019 Calculate value: 2386.000000
# 1020 Calculate value: 5602.000000
# 1021 Calculate value: 3505.000000
# 1022 Calculate value: 11607.000000
# 1023 Calculate value: 9690.000000
# Test Passed!!
# ============================
# Exit process
